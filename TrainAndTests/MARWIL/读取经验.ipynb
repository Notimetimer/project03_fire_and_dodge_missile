# %%
import os
import pickle

def load_il_and_transitions(folder=None):
    """从指定目录加载 il_transitions.pkl 和 transition_dict.pkl（若存在）。"""
    if folder is None:
        # Notebook 中没有 __file__，使用当前工作目录
        folder = os.getcwd()
    il_path = os.path.join(folder, "il_transitions.pkl")
    trans_path = os.path.join(folder, "transition_dict.pkl")
    il = None
    trans = None
    if os.path.isfile(il_path):
        with open(il_path, "rb") as f:
            il = pickle.load(f)
    if os.path.isfile(trans_path):
        with open(trans_path, "rb") as f:
            trans = pickle.load(f)
    return il, trans

# call from notebook
il, trans = load_il_and_transitions(folder="D:/3_Machine_Learning_in_Python/project03_fire_and_dodge_missile/TrainAndTests/MARWIL")

if __name__ == "__main__":
    il, trans = load_il_and_transitions()
    if il is None and trans is None:
        print("No il_transitions.pkl or transition_dict.pkl found in this directory.")
    else:
        if il is not None:
            print("Loaded il_transitions.pkl -> keys:", list(il.keys()))
        if trans is not None:
            print("Loaded transition_dict.pkl -> keys:", list(trans.keys()))
# Out:
# Loaded il_transitions.pkl -> keys: ['states', 'actions', 'returns']
# Loaded transition_dict.pkl -> keys: ['states', 'actions', 'next_states', 'rewards', 'dones']

# %%
import torch

if torch.cuda.is_available():
    print("PyTorch is running on GPU:", torch.cuda.get_device_name(0))
else:
    print("PyTorch is running on CPU")
# Out:
# PyTorch is running on GPU: NVIDIA GeForce RTX 4070 Ti SUPER
